# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports

import os
from openai import OpenAI
import ollama
from dotenv import load_dotenv

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
# Out:
# API key looks good so far

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming

stream = client.chat.completions.create(
    model=MODEL_GPT,
    messages=[
        {"role": "system", "content": "You are a Senior Python Mentor. Explain logic clearly and concisely."},
        {"role": "user", "content": question}
    ],
    stream=True,
)

for chunk in stream:
    content = chunk.choices[0].delta.content
    if content:
        print(content, end="", flush=True)
print("\n")
# Out:
# This line of code utilizes Python's generator and set comprehension features in conjunction with the `yield from` statement. Let's break it down step by step:
#
# 1. **Set Comprehension**: `{book.get("author") for book in books if book.get("author")}`:
#     - This part creates a set of unique authors from a list of `books`.
#     - `books` is assumed to be an iterable (like a list) of dictionaries, where each dictionary represents a book.
#     - For each `book` in `books`, `book.get("author")` attempts to fetch the value associated with the key "author".
#     - The condition `if book.get("author")` ensures that only books with a truthy value for "author" are included. This means that if the author is `None`, an empty string, or any other falsy value, that book will be skipped.
#
# 2. **`yield from`**:
#     - `yield from` is used to yield all values from an iterable. In this case, it yields each unique author obtained from the set comprehension.
#     - This construct is often used in generator functions to simplify yielding values from another iterable.
#
# ### Summary
# Overall, this code snippet collects all unique authors from a list of books and yields them one by one. The set comprehension ensures that you only get distinct names and avoid duplicates, while `yield from` allows the generator to seamlessly yield each author for further processing in whatever context it’s being called.

# %%
# Get Llama 3.2 to answer

try:
    response = ollama.chat(
        model=MODEL_LLAMA,
        messages=[
            {"role": "user", "content": question}
        ]
    )
    print(response['message']['content'])
except Exception as e:
    print(f"Ollama Error: Ensure the Ollama app is running. Error: {e}")
